# %%
import pandas as pd

# %%
crime_df = pd.read_csv('/kaggle/input/crime-split/test_crime_df (1).csv')
crime_df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0         456  Saudi Arabia calls for emergency U.N. Council ...
# 1         784  Many Civilians Martyred as Terrorists Shell Al...
# 2         413  16 Civilians Dead in Coalition Strikes near Ra...
# 3          18  Syrian rebels launched a huge offensive on gov...
# 4         305  Last updated  BEIRUT Air strikes in Syria kill...
#
#                                             metadata domain label
# 0  [{'article': None, 'author': None, 'date': Non...  CRIME  FAKE
# 1  [{'article': None, 'author': None, 'date': Non...  CRIME  TRUE
# 2  [{'article': None, 'author': None, 'date': Non...  CRIME  FAKE
# 3  [{'article': None, 'author': None, 'date': Non...  CRIME  FAKE
# 4  [{'article': None, 'author': None, 'date': Non...  CRIME  TRUE

# %%
health_df = pd.read_csv('/kaggle/input/health-split/test_health_df.csv')
health_df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0        2592  Docket Number: FDA-2020-D-1138 Issued by: Guid...
# 1        7427  Just in | 53 more COVID-19 positive cases dete...
# 2        4737  Post: #1 Corona Virus is a Biological Weapon\n...
# 3        6070  Centre issues order extending #lockdown till M...
# 4       10416   Bitcoin ads that use familiar faces to scam p...
#
#                                             metadata  domain label
# 0  [{'article': None, 'author': None, 'date': Non...  HEALTH  FAKE
# 1  [{'article': None, 'author': None, 'date': '5/...  HEALTH  TRUE
# 2  [{'article': None, 'author': None, 'date': Non...  HEALTH  FAKE
# 3  [{'article': None, 'author': None, 'date': '4/...  HEALTH  TRUE
# 4  [{'article': None, 'author': None, 'date': '4/...  HEALTH  FAKE

# %%
politics_df = pd.read_csv('/kaggle/input/politics-split/test_politics_df.csv')
politics_df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0       46482  KURT NIMMO | OCTOBER 24, 2016 \nHillary Clinto...
# 1       45913  Pginas Libres\nDirectores de BCRP ilegalmente ...
# 2       89143  Starbucks SJWs call cops on customer for reque...
# 3       37203  .@tribelaw says Pres. Trump must be impeached:...
# 4       51500  Britain, U.S. sending planes, troops to deter ...
#
#                                             metadata    domain label
# 0  [{'article': None, 'author': 'stevew', 'date':...  POLITICS  FAKE
# 1  [{'article': None, 'author': 'voltairenet.org'...  POLITICS  FAKE
# 2  [{'article': None, 'author': None, 'date': 'No...  POLITICS  FAKE
# 3  [{'article': None, 'author': 'Pam Key', 'date'...  POLITICS  TRUE
# 4  [{'article': None, 'author': 'Alex Ansary', 'd...  POLITICS  FAKE

# %%
science_df = pd.read_csv('/kaggle/input/science-split/test_science_df.csv')
science_df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0        1593  Scientists retracted claim that sea levels are...
# 1        1603  (Koch Industries) is among the worst in toxic ...
# 2        1503  As soon as renewables were introduced into the...
# 3         991  says Sweet, who has authored several sea-level...
# 4         925  While many scientists have acknowledged the mi...
#
#                                             metadata   domain label
# 0  [{'article': 'Global warming', 'author': None,...  SCIENCE  FAKE
# 1  [{'article': 'Air pollution', 'author': None, ...  SCIENCE  FAKE
# 2  [{'article': 'Electrical grid', 'author': None...  SCIENCE  FAKE
# 3  [{'article': 'Global warming', 'author': None,...  SCIENCE  TRUE
# 4  [{'article': 'Global warming controversy', 'au...  SCIENCE  TRUE

# %%
social_df = pd.read_csv('/kaggle/input/social-split/test_social_df.csv')
social_df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0       21359  Ariana Grande discusses Manchester attack: 'It...
# 1       18558  Kim Kardashian takes kids to Disneyland with K...
# 2       22554  Stephen Colbert welcoming Sean Spicer to the E...
# 3       22329          Coco Rocha Gives Birth To Baby Number Two
# 4       15591  Khloe Kardashian Throws Epic July 4th Bash Wit...
#
#                                             metadata  domain label
# 0  [{'article': None, 'author': None, 'date': Non...  SOCIAL  TRUE
# 1  [{'article': None, 'author': None, 'date': Non...  SOCIAL  TRUE
# 2  [{'article': None, 'author': None, 'date': Non...  SOCIAL  TRUE
# 3  [{'article': None, 'author': None, 'date': Non...  SOCIAL  TRUE
# 4  [{'article': None, 'author': None, 'date': Non...  SOCIAL  TRUE

# %%
testing_all = pd.concat([crime_df,health_df,politics_df,science_df,social_df])
testing_all.head()
# Out:
#    Unnamed: 0                                               text  \
# 0         456  Saudi Arabia calls for emergency U.N. Council ...
# 1         784  Many Civilians Martyred as Terrorists Shell Al...
# 2         413  16 Civilians Dead in Coalition Strikes near Ra...
# 3          18  Syrian rebels launched a huge offensive on gov...
# 4         305  Last updated  BEIRUT Air strikes in Syria kill...
#
#                                             metadata domain label
# 0  [{'article': None, 'author': None, 'date': Non...  CRIME  FAKE
# 1  [{'article': None, 'author': None, 'date': Non...  CRIME  TRUE
# 2  [{'article': None, 'author': None, 'date': Non...  CRIME  FAKE
# 3  [{'article': None, 'author': None, 'date': Non...  CRIME  FAKE
# 4  [{'article': None, 'author': None, 'date': Non...  CRIME  TRUE

# %%
testing_all.to_csv('testing_all.csv')

# %%
len(testing_all)
# Out:
# 10027

# %%
# Testing Datasets

# %%
testing1_df = pd.read_csv('/kaggle/input/testing-all/testing_all1.csv')
testing2_df = pd.read_csv('/kaggle/input/testing-all/testing_all2.csv')

# %%
testing1_df.head()
# Out:
#    Unnamed: 0                                               text  label  \
# 0           0  Does This Video Show a Thwarted Mothers Day Ro...      0
# 1           1  Should You Call #77 or 112 to Contact the Poli...      1
# 2           2  Should You Call #77 or 112 to Contact the Poli...      1
# 3           3  Was a Child Named Chloe Jones Abducted by a Cr...      1
# 4           4  Was a Child Named Chloe Jones Abducted by a Cr...      1
#
#                                             metadata domain
# 0  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 1  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 2  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 3  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 4  [{'article_category_phase1': 'Crime', 'article...  CRIME

# %%
testing2_df.head()
# Out:
#    Unnamed: 0                                               text  label  \
# 0       23835  COX S BAZAR (Reuters) - Grieving Rohingya Musl...      0
# 1       23836  DAR ES SALAAM (Reuters) - Tanzania shut down a...      0
# 2       23837  MADRID (Reuters) - Catalonia s High Court on F...      0
# 3       23838  ERBIL, Iraq (Reuters) - An ban on internationa...      0
# 4       23839  TALLINN (Reuters) - French President Emmanuel ...      0
#
#   metadata  domain
# 0      NaN  SOCIAL
# 1      NaN  SOCIAL
# 2      NaN  SOCIAL
# 3      NaN  SOCIAL
# 4      NaN  SOCIAL

# %%
testing_datasets = pd.concat([testing1_df,testing2_df]) 
len(testing_datasets)
# Out:
# 47671
