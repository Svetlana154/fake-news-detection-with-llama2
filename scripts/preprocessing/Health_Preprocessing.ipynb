# %% [markdown]
# # Setup

# %%
! pip install datasets
# ! pip install pandas
# ! python.exe -m pip install --upgrade pip
# ! pip install matplotlib
# ! pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 21.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 10.0.1
#     Uninstalling pyarrow-10.0.1:
#       Successfully uninstalled pyarrow-10.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 15.0.0 which is incompatible.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datasets import load_dataset
import pandas as pd

# %%
def pd_set_see_full_dataframe():
    # Permanently changes the pandas settings
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    # pd.set_option('display.max_colwidth', -1)

def pd_reset_options():
    # Resets the options
    pd.reset_option('all')

def display_whole_df(df):
    pd_set_see_full_dataframe()
    display(df)
    pd_reset_options()

# %% [markdown]
# # Imports and Merge

# %% [markdown]
# ## FNIR

# %%
df_FNIR_true = pd.read_csv('/content/drive/MyDrive/CSI4900/Datasets/ForTraining/COVID19-FNIR/trueNews.csv')
df_FNIR_false = pd.read_csv('/content/drive/MyDrive/CSI4900/Datasets/ForTraining/COVID19-FNIR/fakeNews.csv')

# %%
df_FNIR_false['Binary Label'] = 1
df_FNIR_true['Binary Label'] = 0

# %%
df_FNIR_false.head()
# Out:
#   Date Posted                                               Link  \
# 0      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 1      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 2      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 3      2/7/20  https://www.poynter.org/?ifcn_misinformation=t...
# 4      2/7/20  https://www.poynter.org/?ifcn_misinformation=c...
#
#                                                 Text  Region   Country  \
# 0    Tencent revealed the real number of deaths.\t\t  Europe    France
# 1   Taking chlorine dioxide helps fight coronavir...  Europe   Germany
# 2   This video shows workmen uncovering a bat-inf...   India     India
# 3   The Asterix comic books and The Simpsons pred...   India     India
# 4   Chinese President Xi Jinping visited a mosque...   India     India
#
#                                          Explanation     Origin  \
# 0                    The screenshot is questionable.    Twitter
# ...

# %%
df_FNIR_true.head()
# Out:
#   Date Posted                                               Link  \
# 0     2/11/20  https://twitter.com/the_hindu/status/122725962...
# 1     2/12/20  https://twitter.com/ndtv/status/12274908434742...
# 2     2/12/20  https://twitter.com/the_hindu/status/122744471...
# 3     2/14/20  https://twitter.com/IndiaToday/status/12282764...
# 4     2/15/20  https://twitter.com/the_hindu/status/122854247...
#
#                                                 Text Region    Username  \
# 0  Just in: Novel coronavirus named 'Covid-19': U...  India   the_hindu
# 1  WHO officially names #coronavirus as Covid-19....  India        ndtv
# 2  The #UN #health agency announced that "COVID-1...  India   the_hindu
# 3  The Indian Embassy in Tokyo has said that one ...  India  indiatoday
# 4  Ground Zero | How Kerala used its experience i...  India   the_hindu
#
#     Publisher  Label  Binary Label
# 0   The Hindu      1             0
# 1        NDTV      1             0
# ...

# %%
df_FNIR_true = df_FNIR_true[['Text', 'Binary Label', 'Link', 'Date Posted']]
df_FNIR_false = df_FNIR_false[['Text', 'Binary Label', 'Origin_URL', 'Date Posted']]

# %%
df_FNIR_true.rename(columns={'Text': 'text', 'Binary Label': 'label', 'Link': 'link', 'Date Posted': 'date'}, inplace=True)

df_FNIR_false.rename(columns={'Text': 'text', 'Binary Label': 'label', 'Origin_URL': 'link', 'Date Posted': 'date'}, inplace=True)

# %%
df_FNIR_true.head()
# Out:
#                                                 text  label  \
# 0  Just in: Novel coronavirus named 'Covid-19': U...      0
# 1  WHO officially names #coronavirus as Covid-19....      0
# 2  The #UN #health agency announced that "COVID-1...      0
# 3  The Indian Embassy in Tokyo has said that one ...      0
# 4  Ground Zero | How Kerala used its experience i...      0
#
#                                                 link     date
# 0  https://twitter.com/the_hindu/status/122725962...  2/11/20
# 1  https://twitter.com/ndtv/status/12274908434742...  2/12/20
# 2  https://twitter.com/the_hindu/status/122744471...  2/12/20
# 3  https://twitter.com/IndiaToday/status/12282764...  2/14/20
# 4  https://twitter.com/the_hindu/status/122854247...  2/15/20

# %%
df_FNIR_false.head()
# Out:
#                                                 text  label  \
# 0    Tencent revealed the real number of deaths.\t\t      1
# 1   Taking chlorine dioxide helps fight coronavir...      1
# 2   This video shows workmen uncovering a bat-inf...      1
# 3   The Asterix comic books and The Simpsons pred...      1
# 4   Chinese President Xi Jinping visited a mosque...      1
#
#                                                 link    date
# 0  https://www.liberation.fr/checknews/2020/02/07...  2/7/20
# 1  https://correctiv.org/faktencheck/medizin-und-...  2/7/20
# 2  https://factcheck.afp.com/video-shows-workmen-...  2/7/20
# 3  https://www.boomlive.in/health/did-the-simpson...  2/7/20
# 4  http://newsmobile.in/articles/2020/02/07/chine...  2/7/20

# %%
df_FNIR = pd.concat([df_FNIR_true, df_FNIR_false], axis=0, ignore_index=True)
df_FNIR.head()
# Out:
#                                                 text  label  \
# 0  Just in: Novel coronavirus named 'Covid-19': U...      0
# 1  WHO officially names #coronavirus as Covid-19....      0
# 2  The #UN #health agency announced that "COVID-1...      0
# 3  The Indian Embassy in Tokyo has said that one ...      0
# 4  Ground Zero | How Kerala used its experience i...      0
#
#                                                 link     date
# 0  https://twitter.com/the_hindu/status/122725962...  2/11/20
# 1  https://twitter.com/ndtv/status/12274908434742...  2/12/20
# 2  https://twitter.com/the_hindu/status/122744471...  2/12/20
# 3  https://twitter.com/IndiaToday/status/12282764...  2/14/20
# 4  https://twitter.com/the_hindu/status/122854247...  2/15/20

# %%
df_FNIR = df_FNIR[['text', 'label']].assign(metadata=df_FNIR.iloc[:,2:].agg(dict,1))

# %%
df_FNIR.head()
# Out:
#                                                 text  label  \
# 0  Just in: Novel coronavirus named 'Covid-19': U...      0
# 1  WHO officially names #coronavirus as Covid-19....      0
# 2  The #UN #health agency announced that "COVID-1...      0
# 3  The Indian Embassy in Tokyo has said that one ...      0
# 4  Ground Zero | How Kerala used its experience i...      0
#
#                                             metadata
# 0  {'link': 'https://twitter.com/the_hindu/status...
# 1  {'link': 'https://twitter.com/ndtv/status/1227...
# 2  {'link': 'https://twitter.com/the_hindu/status...
# 3  {'link': 'https://twitter.com/IndiaToday/statu...
# 4  {'link': 'https://twitter.com/the_hindu/status...

# %%
df_FNIR.to_feather('/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/health_fnir_dataset.feather')

# %%
print("Total number of records:", len(df_FNIR))
print("Label distribution:")
print(df_FNIR['label'].value_counts())
# Out:
# Total number of records: 7588
# Label distribution:
# 1    3795
# 0    3793
# Name: label, dtype: int64

# %% [markdown]
# ## COVID19FN

# %%
df_covid_claims = pd.read_excel('/content/drive/MyDrive/CSI4900/Datasets/ForTesting/health_covid_claims_fake_new_dataset.xlsx')

# %%
df_covid_claims.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  FACEBOOK DELETES MICHIGAN ANTI-LOCKDOWN GROUP ...
# 1           1   Other Viewpoints: COVID-19 is worse than the flu
# 2           2               Bermuda's COVID-19 cases surpass 100
# 3           3  Purdue University says students face 'close to...
# 4           4  THE HIGH COST OF LOCKING DOWN AMERICA: “WE’VE ...
#
#                                                 text      subcategory  label
# 0  Facebook has shuttered a popular group for Mic...       false news      0
# 1  We can now officially put to rest all comparis...             true      1
# 2  The Ministry of Health in Bermuda has confirme...             true      1
# 3  Purdue University President Mitch Daniels, the...  partially false      0
# 4  Locking down much of the country may have help...       false news      0

# %%
df_covid_claims['label'].value_counts()
# Out:
# 1    2061
# 0    1058
# Name: label, dtype: int64

# %%
df_covid_claims = df_covid_claims.rename(columns={'Title ': 'title', 'Label': 'label'})

# %%
df_covid_claims.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  FACEBOOK DELETES MICHIGAN ANTI-LOCKDOWN GROUP ...
# 1           1   Other Viewpoints: COVID-19 is worse than the flu
# 2           2               Bermuda's COVID-19 cases surpass 100
# 3           3  Purdue University says students face 'close to...
# 4           4  THE HIGH COST OF LOCKING DOWN AMERICA: “WE’VE ...
#
#                                                 text      subcategory  label
# 0  Facebook has shuttered a popular group for Mic...       false news      0
# 1  We can now officially put to rest all comparis...             true      1
# 2  The Ministry of Health in Bermuda has confirme...             true      1
# 3  Purdue University President Mitch Daniels, the...  partially false      0
# 4  Locking down much of the country may have help...       false news      0

# %%
df_covid_claims = df_covid_claims[['text', 'label', 'title']].assign(metadata=df_covid_claims.iloc[:,3:].agg(dict,1))

# %%
df_covid_claims.head()
# Out:
#                                                 text  label  \
# 0  Facebook has shuttered a popular group for Mic...      0
# 1  We can now officially put to rest all comparis...      1
# 2  The Ministry of Health in Bermuda has confirme...      1
# 3  Purdue University President Mitch Daniels, the...      0
# 4  Locking down much of the country may have help...      0
#
#                                                title  \
# 0  FACEBOOK DELETES MICHIGAN ANTI-LOCKDOWN GROUP ...
# 1   Other Viewpoints: COVID-19 is worse than the flu
# 2               Bermuda's COVID-19 cases surpass 100
# 3  Purdue University says students face 'close to...
# 4  THE HIGH COST OF LOCKING DOWN AMERICA: “WE’VE ...
#
#                                          metadata
# 0       {'subcategory': 'false news', 'label': 0}
# 1             {'subcategory': 'true', 'label': 1}
# 2             {'subcategory': 'true', 'label': 1}
# 3  {'subcategory': 'partially false', 'label': 0}
# ...

# %%
df_covid_claims['label'].value_counts()
# Out:
# 1    2061
# 0    1058
# Name: label, dtype: int64

# %%
df_covid_claims['label'] = df_covid_claims['label'].replace(False, -1)
df_covid_claims['label'] = df_covid_claims['label'].replace(True, 0)
df_covid_claims['label'] = df_covid_claims['label'].replace(-1, 1)

# %%
df_covid_claims['label'].value_counts()
# Out:
# 1    2061
# 0    1058
# Name: label, dtype: int64

# %%
df_covid_claims.head()
# Out:
#                                                 text  label  \
# 0  Facebook has shuttered a popular group for Mic...      0
# 1  We can now officially put to rest all comparis...      1
# 2  The Ministry of Health in Bermuda has confirme...      1
# 3  Purdue University President Mitch Daniels, the...      0
# 4  Locking down much of the country may have help...      0
#
#                                                title  \
# 0  FACEBOOK DELETES MICHIGAN ANTI-LOCKDOWN GROUP ...
# 1   Other Viewpoints: COVID-19 is worse than the flu
# 2               Bermuda's COVID-19 cases surpass 100
# 3  Purdue University says students face 'close to...
# 4  THE HIGH COST OF LOCKING DOWN AMERICA: “WE’VE ...
#
#                                          metadata
# 0       {'subcategory': 'false news', 'label': 0}
# 1             {'subcategory': 'true', 'label': 1}
# 2             {'subcategory': 'true', 'label': 1}
# 3  {'subcategory': 'partially false', 'label': 0}
# ...

# %% [markdown]
# # Output

# %%
# df_covid_fake_news_dataset.to_feather('../data/covid_fake_news_dataset.feather')
df_covid_claims.to_feather("/content/drive/MyDrive/CSI4900/Datasets/ProcessedTestingDatasets/health_covid_claims_dataset.feather")
# df_FNIR.to_feather('../data/covid_FNIR.feather')
