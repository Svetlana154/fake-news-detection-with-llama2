# %% [markdown]
# Combine the preprocessed datasets in the following manner:
# 1. For classification training: all training datasets, regardless of domain
# 2. For classification testing: all testing datasets, regardless of domain
# 3. For domain-specific training: all training datasets in specific domain
# 4. For domain-specific testing: all testing datasets in specific domain

# %% [markdown]
# # 1. Combining Datasets for News Category Classification

# %% [markdown]
# ## Training

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_crime = pd.read_feather("/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/crime_dataset.feather") # crime
df_crime['metadata'] = df_crime['metadata'].apply(lambda x: [x])
df_crime['domain'] = 'CRIME'
display(df_crime.head())
# Out:
#                                                 text  label  \
# 0  Syria attack symptoms consistent with nerve ag...      1
# 1  at 0914 Homs governor says U.S. attack caused ...      1
# 2  Death toll from Aleppo bomb attack at least 11...      1
# 3  Aleppo bomb blast kills six Syrian state TV. A...      1
# 4  29 Syria Rebels Dead in Fighting for Key Alepp...      1
#
#                                             metadata domain
# 0  [{'metadata': {'date': '4/5/2017', 'location':...  CRIME
# 1  [{'metadata': {'date': '4/7/2017', 'location':...  CRIME
# 2  [{'metadata': {'date': '4/16/2017', 'location'...  CRIME
# 3  [{'metadata': {'date': '4/19/2017', 'location'...  CRIME
# 4  [{'metadata': {'date': '7/10/2016', 'location'...  CRIME

# %%
df_crime[df_crime['text'].str.contains("security HQ in central Syria")]
# Out:
#                                                   text  label  \
# 283  Five dead in blast by security HQ in central S...      1
#
#                                               metadata domain
# 283  [{'metadata': {'date': '3/4/2014', 'location':...  CRIME

# %%
display(df_crime['label'].value_counts())
# Out:
# 0    426
# 1    378
# Name: label, dtype: int64

# %%
df_science = pd.read_feather("/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/climate_dataset.feather") # science
df_science['domain'] = 'SCIENCE'
display(df_science.head())
# Out:
#                                                 text  label  \
# 0  Global warming is driving polar bears toward e...      0
# 1  The sun has gone into ‘lockdown’ which could c...      0
# 2  They tell us that we are the primary forces co...      0
# 3  The Great Barrier Reef is experiencing the mos...      0
# 4  Volcanoes Melting West Antarctic Glaciers, Not...      0
#
#                                             metadata   domain
# 0  [{'article': 'Extinction risk from global warm...  SCIENCE
# 1  [{'article': 'Famine', 'entropy': 0.0, 'eviden...  SCIENCE
# 2  [{'article': 'Carbon dioxide', 'entropy': 0.0,...  SCIENCE
# 3  [{'article': 'Coral bleaching', 'entropy': 0.0...  SCIENCE
# 4  [{'article': 'Antarctica', 'entropy': 0.693147...  SCIENCE

# %%
display(df_science['label'].value_counts())
# Out:
# 0    654
# 1    253
# Name: label, dtype: int64

# %%
df_health_fn = pd.read_feather("/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/health_fn_dataset.feather") # health (1 out of 2)
df_health_fn['metadata'] = df_health_fn['metadata'].apply(lambda x: [x])
df_health_fn['domain'] = 'HEALTH'
display(df_health_fn.head())
# Out:
#                                                 text  label  \
# 0  Facebook has shuttered a popular group for Mic...      1
# 1  We can now officially put to rest all comparis...      0
# 2  The Ministry of Health in Bermuda has confirme...      0
# 3  Purdue University President Mitch Daniels, the...      1
# 4  Locking down much of the country may have help...      1
#
#                                             metadata  domain
# 0  [{'subcategory': 'false news', 'title': 'FACEB...  HEALTH
# 1  [{'subcategory': 'true', 'title': 'Other Viewp...  HEALTH
# 2  [{'subcategory': 'true', 'title': 'Bermuda's C...  HEALTH
# 3  [{'subcategory': 'partially false', 'title': '...  HEALTH
# 4  [{'subcategory': 'false news', 'title': 'THE H...  HEALTH

# %%
df_health_fn['domain'].value_counts()
# Out:
# HEALTH    3119
# Name: domain, dtype: int64

# %%
df_health_fnir = pd.read_feather("/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/health_fnir_dataset.feather") # health (2 out of 2)
df_health_fnir['metadata'] = df_health_fnir['metadata'].apply(lambda x: [x])
df_health_fnir['domain'] = 'HEALTH'
display(df_health_fnir.head())
# Out:
#                                                 text  label  \
# 0  Just in: Novel coronavirus named 'Covid-19': U...      0
# 1  WHO officially names #coronavirus as Covid-19....      0
# 2  The #UN #health agency announced that "COVID-1...      0
# 3  The Indian Embassy in Tokyo has said that one ...      0
# 4  Ground Zero | How Kerala used its experience i...      0
#
#                                             metadata  domain
# 0  [{'date': '2/11/20', 'link': 'https://twitter....  HEALTH
# 1  [{'date': '2/12/20', 'link': 'https://twitter....  HEALTH
# 2  [{'date': '2/12/20', 'link': 'https://twitter....  HEALTH
# 3  [{'date': '2/14/20', 'link': 'https://twitter....  HEALTH
# 4  [{'date': '2/15/20', 'link': 'https://twitter....  HEALTH

# %%
df_health_fnir['domain'].value_counts()
# Out:
# HEALTH    7588
# Name: domain, dtype: int64

# %%
df_health = pd.concat([df_health_fn, df_health_fnir], ignore_index=True) # combining health train set
display(df_health.head())
# Out:
#                                                 text  label  \
# 0  Facebook has shuttered a popular group for Mic...      1
# 1  We can now officially put to rest all comparis...      0
# 2  The Ministry of Health in Bermuda has confirme...      0
# 3  Purdue University President Mitch Daniels, the...      1
# 4  Locking down much of the country may have help...      1
#
#                                             metadata  domain
# 0  [{'subcategory': 'false news', 'title': 'FACEB...  HEALTH
# 1  [{'subcategory': 'true', 'title': 'Other Viewp...  HEALTH
# 2  [{'subcategory': 'true', 'title': 'Bermuda's C...  HEALTH
# 3  [{'subcategory': 'partially false', 'title': '...  HEALTH
# 4  [{'subcategory': 'false news', 'title': 'THE H...  HEALTH

# %%
df_health['domain'].value_counts()
# Out:
# HEALTH    10707
# Name: domain, dtype: int64

# %%
df_social = pd.read_feather("/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/social_dataset.feather") # social
df_social['metadata'] = df_social['metadata'].apply(lambda x: [x])
df_social['domain'] = 'SOCIAL'
display(df_social.head())
# Out:
#                                                 text  label  \
# 0  Teen Mom Star Jenelle Evans' Wedding Dress Is ...      0
# 1  Kylie Jenner refusing to discuss Tyga on Life ...      0
# 2                                      Quinn Perkins      0
# 3  I Tried Kim Kardashian's Butt Workout & Am For...      0
# 4  Celine Dion donates concert proceeds to Vegas ...      0
#
#                                             metadata  domain
# 0  [{'link': 'https://www.brides.com/story/teen-m...  SOCIAL
# 1  [{'link': 'https://www.dailymail.co.uk/tvshowb...  SOCIAL
# 2  [{'link': 'https://en.wikipedia.org/wiki/Quinn...  SOCIAL
# 3  [{'link': 'https://www.refinery29.com/en-us/20...  SOCIAL
# 4  [{'link': 'https://www.cnn.com/2017/10/04/ente...  SOCIAL

# %%
df_social['label'].value_counts()
# Out:
# 0    16817
# 1     5323
# Name: label, dtype: int64

# %%
df_politics_liar = pd.read_feather('/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/politics_liar_dataset.feather')
df_politics_liar['metadata'] = df_politics_liar['metadata'].apply(lambda x: [x])
df_politics_liar['domain'] = 'POLITICS'
display(df_politics_liar.head())
# Out:
#                                                 text  label  \
# 0  Says the Annies List political group supports ...      1
# 1  When did the decline of coal start? It started...      0
# 2  Hillary Clinton agrees with John McCain "by vo...      0
# 3  Health care reform legislation is likely to ma...      1
# 4  The economic turnaround started at the end of ...      0
#
#                                             metadata    domain
# 0  [{'author': 'dwayne-bohac', 'context': 'a mail...  POLITICS
# 1  [{'author': 'scott-surovell', 'context': 'a fl...  POLITICS
# 2  [{'author': 'barack-obama', 'context': 'Denver...  POLITICS
# 3  [{'author': 'blog-posting', 'context': 'a news...  POLITICS
# 4  [{'author': 'charlie-crist', 'context': 'an in...  POLITICS

# %%
df_politics_liar['label'].value_counts()
# Out:
# 0    7167
# 1    5669
# Name: label, dtype: int64

# %%
df_politics_fake_news = pd.read_feather('/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/politics_fakenews_dataset.feather')
df_politics_fake_news['metadata'] = df_politics_fake_news['metadata'].apply(lambda x: [x])
df_politics_fake_news['domain'] = 'POLITICS'
display(df_politics_fake_news.head())
# Out:
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                             metadata    domain
# 0  [{'author': 'Darrell Lucus', 'title': 'House D...  POLITICS
# 1  [{'author': 'Daniel J. Flynn', 'title': 'FLYNN...  POLITICS
# 2  [{'author': 'Consortiumnews.com', 'title': 'Wh...  POLITICS
# 3  [{'author': 'Jessica Purkiss', 'title': '15 Ci...  POLITICS
# 4  [{'author': 'Howard Portnoy', 'title': 'Irania...  POLITICS

# %%
df_politics_fake_news['label'].value_counts()
# Out:
# 1    10413
# 0    10387
# Name: label, dtype: int64

# %%
df_politics_isot = pd.read_feather('/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/politics_isot_dataset.feather')
df_politics_isot['metadata'] = df_politics_isot['metadata'].apply(lambda x: [x])
df_politics_isot['domain'] = 'POLITICS'
display(df_politics_isot.head())
# Out:
#                                                 text  label  \
# 0  WASHINGTON (Reuters) - The head of a conservat...      0
# 1  WASHINGTON (Reuters) - Transgender people will...      0
# 2  WASHINGTON (Reuters) - The special counsel inv...      0
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      0
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      0
#
#                                             metadata    domain
# 0  [{'author': None, 'date': 'December 31, 2017 '...  POLITICS
# 1  [{'author': None, 'date': 'December 29, 2017 '...  POLITICS
# 2  [{'author': None, 'date': 'December 31, 2017 '...  POLITICS
# 3  [{'author': None, 'date': 'December 30, 2017 '...  POLITICS
# 4  [{'author': None, 'date': 'December 29, 2017 '...  POLITICS

# %%
df_politics_isot['label'].value_counts()
# Out:
# 1    23481
# 0    21417
# Name: label, dtype: int64

# %%
# df_politics = pd.concat([df_politics_liar, df_politics_fake_news, df_politics_isot], ignore_index=True) # combining politics train set
df_politics = pd.concat([df_politics_fake_news, df_politics_isot], ignore_index=True) # combining politics train set [removed liar]

display(df_politics.head())
# Out:
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                             metadata    domain
# 0  [{'author': 'Darrell Lucus', 'title': 'House D...  POLITICS
# 1  [{'author': 'Daniel J. Flynn', 'title': 'FLYNN...  POLITICS
# 2  [{'author': 'Consortiumnews.com', 'title': 'Wh...  POLITICS
# 3  [{'author': 'Jessica Purkiss', 'title': '15 Ci...  POLITICS
# 4  [{'author': 'Howard Portnoy', 'title': 'Irania...  POLITICS

# %%
df_training = pd.concat([df_crime, df_science, df_health_fnir, df_social, df_politics], ignore_index=True) # combining all training data
display(df_training.head())
# Out:
#                                                 text  label  \
# 0  Syria attack symptoms consistent with nerve ag...      1
# 1  at 0914 Homs governor says U.S. attack caused ...      1
# 2  Death toll from Aleppo bomb attack at least 11...      1
# 3  Aleppo bomb blast kills six Syrian state TV. A...      1
# 4  29 Syria Rebels Dead in Fighting for Key Alepp...      1
#
#                                             metadata domain
# 0  [{'metadata': {'date': '4/5/2017', 'location':...  CRIME
# 1  [{'metadata': {'date': '4/7/2017', 'location':...  CRIME
# 2  [{'metadata': {'date': '4/16/2017', 'location'...  CRIME
# 3  [{'metadata': {'date': '4/19/2017', 'location'...  CRIME
# 4  [{'metadata': {'date': '7/10/2016', 'location'...  CRIME

# %%
display(df_training['label'].value_counts())
# Out:
# 0    55555
# 1    44701
# Name: label, dtype: int64

# %%
display(df_training['domain'].value_counts())
# Out:
# POLITICS    65698
# SOCIAL      22140
# HEALTH      10707
# SCIENCE       907
# CRIME         804
# Name: domain, dtype: int64

# %%
s = 'The German government made a "secret plan" about coronavirus in 2012 that foretold the pandemic.'

# %%
'' in s
# Out:
# True

# %%
df_training['text'] = df_training['text'].astype(str).str.replace("","")

# %%
df_training[df_training['text'].astype(str).str.contains("")]
# Out:
# Empty DataFrame
# Columns: [text, label, metadata, domain]
# Index: []

# %%
df_training.to_feather('/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/LiarRemoved/training_dataset.feather')
