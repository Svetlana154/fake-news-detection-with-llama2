# %% [markdown]
# Combine the preprocessed datasets in the following manner:
# 1. For classification training: all training datasets, regardless of domain
# 2. For classification testing: all testing datasets, regardless of domain
# 3. For domain-specific training: all training datasets in specific domain
# 4. For domain-specific testing: all testing datasets in specific domain

# %% [markdown]
# # 1. Combining Datasets for News Category Classification

# %% [markdown]
# italicized text## Testing

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_crime = pd.read_feather("/content/drive/MyDrive/CSI4900/Datasets/ProcessedTestingDatasets/crime_dataset.feather") # crime
df_crime['metadata'] = df_crime['metadata'].apply(lambda x: [x])
df_crime['domain'] = 'CRIME'
display(df_crime.head())
# Out:
#    index                                               text  label  \
# 0    309  Does This Video Show a Thwarted Mother’s Day R...      0
# 1  20608  Should You Call #77 or 112 to Contact the Poli...      1
# 2  20609  Should You Call #77 or 112 to Contact the Poli...      1
# 3  21177  Was a Child Named Chloe Jones Abducted by a ‘C...      1
# 4  21178  Was a Child Named Chloe Jones Abducted by a ‘C...      1
#
#                                             metadata domain
# 0  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 1  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 2  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 3  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 4  [{'article_category_phase1': 'Crime', 'article...  CRIME

# %%
display(df_crime['label'].value_counts())
# Out:
# label
# 1    510
# 0    308
# Name: count, dtype: int64

# %%
df_science = pd.read_feather("/content/drive/MyDrive/CSI4900/Datasets/ProcessedTestingDatasets/science_isot.feather") # science
df_science['domain'] = 'SCIENCE'
display(df_science.head())
# Out:
#    index                                               text  label  \
# 0      0  Donald Trump stopped in Hawaii, which is total...      1
# 1      1  Who knew that Rick Perry would come up with an...      1
# 2      2  Like increasing numbers of heartless people on...      1
# 3      3  Let s just put it this way, if world leaders r...      1
# 4      4  Leave it to Donald Trump to exploit a tragedy....      1
#
#                                                title subject       date  \
# 0   Hawaiians Had The Perfect Signs To Infuriate ...    News 2017-11-04
# 1   Trumpâ€™s Energy Secretary Has An Idea For St...    News 2017-11-02
# 2   Bill Oâ€™Reilly Writes INFURIATING Blog Post ...    News 2017-10-02
# 3   Global Survey HUMILIATES Trump After He Claim...    News 2017-09-20
# 4   Trump Shamefully Uses Hurricane Devastation T...    News 2017-09-13
#
#     domain
# 0  SCIENCE
# 1  SCIENCE
# 2  SCIENCE
# 3  SCIENCE
# 4  SCIENCE

# %%
display(df_science['label'].value_counts())
# Out:
# label
# 0    467
# 1    406
# Name: count, dtype: int64

# %%
df_health = pd.read_feather("/content/drive/MyDrive/CSI4900/Datasets/ProcessedTestingDatasets/health_covid_claims_dataset.feather") # health (1 out of 2)
df_health['metadata'] = df_health['metadata'].apply(lambda x: [x])
df_health['domain'] = 'HEALTH'
display(df_health.head())
# Out:
#                                                 text  label  \
# 0  Facebook has shuttered a popular group for Mic...      0
# 1  We can now officially put to rest all comparis...      1
# 2  The Ministry of Health in Bermuda has confirme...      1
# 3  Purdue University President Mitch Daniels, the...      0
# 4  Locking down much of the country may have help...      0
#
#                                                title  \
# 0  FACEBOOK DELETES MICHIGAN ANTI-LOCKDOWN GROUP ...
# 1   Other Viewpoints: COVID-19 is worse than the flu
# 2               Bermuda's COVID-19 cases surpass 100
# 3  Purdue University says students face 'close to...
# 4  THE HIGH COST OF LOCKING DOWN AMERICA: “WE’VE ...
#
#                                            metadata  domain
# 0       [{'label': 0, 'subcategory': 'false news'}]  HEALTH
# 1             [{'label': 1, 'subcategory': 'true'}]  HEALTH
# 2             [{'label': 1, 'subcategory': 'true'}]  HEALTH
# ...

# %%
df_health['domain'].value_counts()
# Out:
# domain
# HEALTH    3119
# Name: count, dtype: int64

# %%
df_health['label'].value_counts()
# Out:
# label
# 1    2061
# 0    1058
# Name: count, dtype: int64

# %%
df_social = pd.read_feather("/content/drive/MyDrive/CSI4900/Datasets/ProcessedTestingDatasets/social_isot.feather") # social
df_social['domain'] = 'SOCIAL'
display(df_social.head())
# Out:
#    level_0  index                                               text  label  \
# 0        0      0  Donald Trump just couldn t wish all Americans ...      1
# 1        1      1  House Intelligence Committee Chairman Devin Nu...      1
# 2        2      2  On Friday, it was revealed that former Milwauk...      1
# 3        3      3  On Christmas day, Donald Trump announced that ...      1
# 4        4      4  Pope Francis used his annual Christmas Day mes...      1
#
#                                                title subject       date  \
# 0   Donald Trump Sends Out Embarrassing New Yearâ...    News 2017-12-31
# 1   Drunk Bragging Trump Staffer Started Russian ...    News 2017-12-31
# 2   Sheriff David Clarke Becomes An Internet Joke...    News 2017-12-30
# 3   Trump Is So Obsessed He Even Has Obamaâ€™s Na...    News 2017-12-29
# 4   Pope Francis Just Called Out Donald Trump Dur...    News 2017-12-25
#
#    domain
# 0  SOCIAL
# 1  SOCIAL
# 2  SOCIAL
# 3  SOCIAL
# 4  SOCIAL

# %%
df_social['label'].value_counts()
# Out:
# label
# 1    11932
# 0     9777
# Name: count, dtype: int64

# %%
df_politics_politifact = pd.read_feather('/content/drive/MyDrive/CSI4900/Datasets/ProcessedTestingDatasets/politics_politifact.feather')
df_politics_politifact['metadata'] = df_politics_politifact['metadata'].apply(lambda x: [x])
df_politics_politifact['domain'] = 'POLITICS'
display(df_politics_politifact.head())
# Out:
#                                                 text  label  \
# 0  John McCain opposed bankruptcy protections for...      0
# 1  "Bennie Thompson actively cheer-led riots in t...      1
# 2  Says Maggie Hassan was "out of state on 30 day...      0
# 3  "BUSTED: CDC Inflated COVID Numbers, Accused o...      1
# 4  "I'm the only (Republican) candidate that has ...      0
#
#                                             metadata    domain
# 0  [{'author': 'Barack Obama', 'factcheck_analysi...  POLITICS
# 1  [{'author': 'Matt Gaetz', 'factcheck_analysis_...  POLITICS
# 2  [{'author': 'Kelly Ayotte', 'factcheck_analysi...  POLITICS
# 3  [{'author': 'Bloggers', 'factcheck_analysis_li...  POLITICS
# 4  [{'author': 'Bobby Jindal', 'factcheck_analysi...  POLITICS

# %%
df_politics_politifact['label'].value_counts()
# Out:
# label
# 1    11760
# 0     9392
# Name: count, dtype: int64

# %%
df_politics_fake_news = pd.read_feather('/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/politics_fakenews_dataset.feather')
df_politics_fake_news['metadata'] = df_politics_fake_news['metadata'].apply(lambda x: [x])
df_politics_fake_news['domain'] = 'POLITICS'
display(df_politics_fake_news.head())
# Out:
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                             metadata    domain
# 0  [{'author': 'Darrell Lucus', 'title': 'House D...  POLITICS
# 1  [{'author': 'Daniel J. Flynn', 'title': 'FLYNN...  POLITICS
# 2  [{'author': 'Consortiumnews.com', 'title': 'Wh...  POLITICS
# 3  [{'author': 'Jessica Purkiss', 'title': '15 Ci...  POLITICS
# 4  [{'author': 'Howard Portnoy', 'title': 'Irania...  POLITICS

# %%
df_politics_fake_news['label'].value_counts()
# Out:
# 1    10413
# 0    10387
# Name: label, dtype: int64

# %%
df_politics_isot = pd.read_feather('/content/drive/MyDrive/CSI4900/Datasets/ProcessedTrainingDatasets/politics_isot_dataset.feather')
df_politics_isot['metadata'] = df_politics_isot['metadata'].apply(lambda x: [x])
df_politics_isot['domain'] = 'POLITICS'
display(df_politics_isot.head())
# Out:
#                                                 text  label  \
# 0  WASHINGTON (Reuters) - The head of a conservat...      0
# 1  WASHINGTON (Reuters) - Transgender people will...      0
# 2  WASHINGTON (Reuters) - The special counsel inv...      0
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      0
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      0
#
#                                             metadata    domain
# 0  [{'author': None, 'date': 'December 31, 2017 '...  POLITICS
# 1  [{'author': None, 'date': 'December 29, 2017 '...  POLITICS
# 2  [{'author': None, 'date': 'December 31, 2017 '...  POLITICS
# 3  [{'author': None, 'date': 'December 30, 2017 '...  POLITICS
# 4  [{'author': None, 'date': 'December 29, 2017 '...  POLITICS

# %%
df_politics_isot['label'].value_counts()
# Out:
# 1    23481
# 0    21417
# Name: label, dtype: int64

# %%
# df_politics = pd.concat([df_politics_liar, df_politics_fake_news, df_politics_isot], ignore_index=True) # combining politics train set
df_politics = pd.concat([df_politics_fake_news, df_politics_isot], ignore_index=True) # combining politics train set [removed liar]

display(df_politics.head())
# Out:
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                             metadata    domain
# 0  [{'author': 'Darrell Lucus', 'title': 'House D...  POLITICS
# 1  [{'author': 'Daniel J. Flynn', 'title': 'FLYNN...  POLITICS
# 2  [{'author': 'Consortiumnews.com', 'title': 'Wh...  POLITICS
# 3  [{'author': 'Jessica Purkiss', 'title': '15 Ci...  POLITICS
# 4  [{'author': 'Howard Portnoy', 'title': 'Irania...  POLITICS

# %%
df_testing = pd.concat([df_crime, df_science, df_health, df_social, df_politics_politifact], ignore_index=True) # combining all training data
display(df_testing.head())
# Out:
#      index                                               text  label  \
# 0    309.0  Does This Video Show a Thwarted Mother’s Day R...      0
# 1  20608.0  Should You Call #77 or 112 to Contact the Poli...      1
# 2  20609.0  Should You Call #77 or 112 to Contact the Poli...      1
# 3  21177.0  Was a Child Named Chloe Jones Abducted by a ‘C...      1
# 4  21178.0  Was a Child Named Chloe Jones Abducted by a ‘C...      1
#
#                                             metadata domain title subject  \
# 0  [{'article_category_phase1': 'Crime', 'article...  CRIME   NaN     NaN
# 1  [{'article_category_phase1': 'Crime', 'article...  CRIME   NaN     NaN
# 2  [{'article_category_phase1': 'Crime', 'article...  CRIME   NaN     NaN
# 3  [{'article_category_phase1': 'Crime', 'article...  CRIME   NaN     NaN
# 4  [{'article_category_phase1': 'Crime', 'article...  CRIME   NaN     NaN
#
#   date  level_0
# 0  NaT      NaN
# 1  NaT      NaN
# 2  NaT      NaN
# 3  NaT      NaN
# 4  NaT      NaN

# %%
df_testing.drop(['index','title','subject','date','level_0'],axis=1,inplace=True)
df_testing.head()
# Out:
#                                                 text  label  \
# 0  Does This Video Show a Thwarted Mother’s Day R...      0
# 1  Should You Call #77 or 112 to Contact the Poli...      1
# 2  Should You Call #77 or 112 to Contact the Poli...      1
# 3  Was a Child Named Chloe Jones Abducted by a ‘C...      1
# 4  Was a Child Named Chloe Jones Abducted by a ‘C...      1
#
#                                             metadata domain
# 0  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 1  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 2  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 3  [{'article_category_phase1': 'Crime', 'article...  CRIME
# 4  [{'article_category_phase1': 'Crime', 'article...  CRIME

# %%
display(df_testing['label'].value_counts())
# Out:
# label
# 1    26669
# 0    21002
# Name: count, dtype: int64

# %%
display(df_testing['domain'].value_counts())
# Out:
# domain
# SOCIAL      21709
# POLITICS    21152
# HEALTH       3119
# SCIENCE       873
# CRIME         818
# Name: count, dtype: int64

# %%
df_testing['text'] = df_testing['text'].str.encode('ascii', 'ignore').str.decode('ascii')

# %%
df_testing1 = df_testing.iloc[:len(df_testing)//2,:]
df_testing2 = df_testing.iloc[len(df_testing)//2:,:]

# %%
display(df_testing1)
display(df_testing2)
# Out:
#                                                     text  label  \
# 0      Does This Video Show a Thwarted Mothers Day Ro...      0
# 1      Should You Call #77 or 112 to Contact the Poli...      1
# 2      Should You Call #77 or 112 to Contact the Poli...      1
# 3      Was a Child Named Chloe Jones Abducted by a Cr...      1
# 4      Was a Child Named Chloe Jones Abducted by a Cr...      1
# ...                                                  ...    ...
# 23830  HAVANA (Reuters) - The United States  decision...      0
# 23831  WASHINGTON (Reuters) - The U.S. led coalition ...      0
# 23832  KABUL (Reuters) - Islamic State claimed respon...      0
# 23833  WASHINGTON (Reuters) - The U.S. Justice Depart...      0
# 23834  COX S BAZAR, Bangladesh/UNITED NATIONS (Reuter...      0
#
#                                                 metadata  domain
# 0      [{'article_category_phase1': 'Crime', 'article...   CRIME
# 1      [{'article_category_phase1': 'Crime', 'article...   CRIME
# ...

# %%
df_testing1.to_csv('/content/drive/MyDrive/CSI4900/Datasets/ProcessedTestingDatasets/testing_all1.csv')
df_testing2.to_csv('/content/drive/MyDrive/CSI4900/Datasets/ProcessedTestingDatasets/testing_all2.csv')
